# %% [markdown]
# <h3 style="color:red;">Make sure the Docker service running before running this notebook</h3>
#
# # Section 1: Launching HaGrid nodes

# %%
! hagrid launch {"Domain_2"} to docker:8002 --build-src=0.7.0
# Out:
# ✅ Updated HAGrid from branch: 0.7.0m
# ⠏ Updating HAGrid from branch: 0.7.0
# ⠋ Checking for Docker Service   ice
# ✅ Docker service is running
# ✅ Git 2.37.1
# ✅ Docker 20.10.22
# ✅ Docker Compose 2.15.1
#
#
#  _   _       _     _                 _   _                       _
# | | | |     | |   | |               | | | |                     | |
# | |_| | ___ | | __| |   ___  _ __   | |_| | __ _ _ __ _ __ _   _| |
# |  _  |/ _ \| |/ _` |  / _ \| '_ \  |  _  |/ _` | '__| '__| | | | |
# | | | | (_) | | (_| | | (_) | | | | | | | | (_| | |  | |  | |_| |_|
# \_| |_/\___/|_|\__,_|  \___/|_| |_| \_| |_/\__,_|_|  |_|   \__, (_)
#                                                             __/ |
#                                                            |___/
#
# Launching a PyGrid Domain node on port 8002!
#
#   - NAME: domain_2
#   - RELEASE: production
#   - ARCH: linux/arm64
#   - TYPE: domain
#   - DOCKER_TAG: latest
#   - HAGRID_VERSION: 0.2.126
#   - PORT: 8002
#   - DOCKER COMPOSE: v2.15.1
#
#
# ⠋ Launching Containers
#   ✅ Pulling [9 / 9] ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.00%   0m 88.89%
# ⠹  Launching [8 / 9] ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━ 88.89%
#
# ⠋ Checking node API
# ✅ domain_2 Domain Containers Createdner Creation0m
# ✅ Backendm Starting Backendeation
# ✅ Startup Completeting Backend
# ⠧ Starting Backend
# ┏━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━┓
# ┃ PyGrid    ┃ Info                                      ┃ 600 ┃
# ┡━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━┩
# │ UI (βeta) │ http://localhost:8002/login               │ ✅  │
# │ api       │ http://localhost:8002/api/v1/openapi.json │ ✅  │
# └───────────┴───────────────────────────────────────────┴─────┘
# ╭────────────────────────────────────────────────────╮
# │ ✨ To view container logs run hagrid logs domain_2 │
# ╰────────────────────────────────────────────────────╯

# %%
from utils import *

domain_user = sy.login(email="info@openmined.org", 
                       password="changethis", 
                       port=8002)
# Out:
# WARNING: CHANGE YOUR USERNAME AND PASSWORD!!!
#
# Anyone can login as an admin to your node right now because your password is still the default PySyft username and password!!!
#
# Connecting to localhost... done! 	 Logging into domain_2... done!

# %%
! docker compose ls
# Out:
# NAME                STATUS              CONFIG FILES
# domain_1            running(11)         /Users/neeleshkarthikeyan/.hagrid/PySyft/packages/grid/docker-compose.yml
# domain_2            running(11)         /Users/neeleshkarthikeyan/.hagrid/PySyft/packages/grid/docker-compose.yml
# local_network       running(11)         /Users/neeleshkarthikeyan/.hagrid/PySyft/packages/grid/docker-compose.yml

# %%
! docker container ls
# Out:
# CONTAINER ID   IMAGE                                 COMMAND                  CREATED         STATUS         PORTS                                                                               NAMES
# 72f84f49c7f9   openmined/grid-frontend:latest        "/docker-entrypoint.…"   5 minutes ago   Up 5 minutes   80/tcp                                                                              domain_1-frontend-1
# 367b5187f6f4   openmined/grid-frontend:latest        "/docker-entrypoint.…"   5 minutes ago   Up 5 minutes   80/tcp                                                                              domain_2-frontend-1
# 13319163f6e7   chrislusf/seaweedfs:latest            "/entrypoint.sh serv…"   5 minutes ago   Up 5 minutes   7333/tcp, 8080/tcp, 8333/tcp, 8888/tcp, 9333/tcp, 18080/tcp, 18888/tcp, 19333/tcp   domain_2-seaweedfs-1
# f9ab9a156c0e   openmined/grid-backend:latest         "/start.sh"              5 minutes ago   Up 5 minutes                                                                                       domain_2-backend-1
# c3a79657cd0d   openmined/grid-vpn-tailscale:latest   "sh -c '/tailscale/t…"   5 minutes ago   Up 5 minutes                                                                                       domain_2-tailscale-1
# 0b4e8bcf6526   openmined/grid-backend:latest         "/worker-start.sh"       5 minutes ago   Up 5 minutes                                                                                       domain_2-celeryworker-1
# 2061e1ef333d   openmined/grid-backend:latest         "/start.sh"              5 minutes ago   Up 5 minutes                                                                                       domain_2-backend_stream-1
# 5f7f06984bf0   openmined/grid-backend:latest         "/worker-start.sh"       5 minutes ago   Up 5 minutes                                                                                       domain_1-celeryworker-1
# 0ecb5773c8c0   openmined/grid-backend:latest         "/start.sh"              5 minutes ago   Up 5 minutes                                                                                       domain_1-backend_stream-1
# c543915a9d8b   chrislusf/seaweedfs:latest            "/entrypoint.sh serv…"   5 minutes ago   Up 5 minutes   7333/tcp, 8080/tcp, 8333/tcp, 8888/tcp, 9333/tcp, 18080/tcp, 18888/tcp, 19333/tcp   domain_1-seaweedfs-1
# ab48f0c4dd61   openmined/grid-backend:latest         "/start.sh"              5 minutes ago   Up 5 minutes                                                                                       domain_1-backend-1
# 2fae7068b451   openmined/grid-vpn-tailscale:latest   "sh -c '/tailscale/t…"   5 minutes ago   Up 5 minutes                                                                                       domain_1-tailscale-1
# fefb26180d80   traefik:v2.8.1                        "/entrypoint.sh trae…"   5 minutes ago   Up 5 minutes   80/tcp, 0.0.0.0:8002->81/tcp                                                        domain_2-proxy-1
# c57d491a8dd9   traefik:v2.8.1                        "/entrypoint.sh trae…"   5 minutes ago   Up 5 minutes   80/tcp, 0.0.0.0:8001->81/tcp                                                        domain_1-proxy-1
# 05e6fb176c6e   qoomon/docker-host                    "/entrypoint.sh"         5 minutes ago   Up 5 minutes                                                                                       domain_2-docker-host-1
# 0d4ab6165fe5   qoomon/docker-host                    "/entrypoint.sh"         5 minutes ago   Up 5 minutes                                                                                       domain_1-docker-host-1
# 5e547247e8cb   openmined/grid-frontend:latest        "/docker-entrypoint.…"   5 minutes ago   Up 5 minutes   80/tcp                                                                              local_network-frontend-1
# eea9555971a1   openmined/grid-backend:latest         "/worker-start.sh"       5 minutes ago   Up 5 minutes                                                                                       local_network-celeryworker-1
# d6364c064a29   openmined/grid-backend:latest         "/start.sh"              5 minutes ago   Up 5 minutes                                                                                       local_network-backend_stream-1
# 88820d01b1ba   openmined/grid-vpn-tailscale:latest   "sh -c '/tailscale/t…"   5 minutes ago   Up 5 minutes                                                                                       local_network-tailscale-1
# aabb37481da7   openmined/grid-vpn-headscale:latest   "sh -c '/headscale/h…"   5 minutes ago   Up 5 minutes   8080/tcp                                                                            local_network-headscale-1
# f2e3c5c943e9   openmined/grid-backend:latest         "/start.sh"              5 minutes ago   Up 5 minutes                                                                                       local_network-backend-1
# 2e34c76aab29   traefik:v2.8.1                        "/entrypoint.sh trae…"   5 minutes ago   Up 5 minutes   80/tcp, 0.0.0.0:8000->81/tcp                                                        local_network-proxy-1
# 36213b922a7e   qoomon/docker-host                    "/entrypoint.sh"         5 minutes ago   Up 5 minutes                                                                                       local_network-docker-host-1
# 3decfdb13857   redis:6.2                             "docker-entrypoint.s…"   22 hours ago    Up 5 minutes   6379/tcp                                                                            domain_2-redis-1
# 9c3be89e9e29   rabbitmq:3                            "docker-entrypoint.s…"   22 hours ago    Up 6 minutes   4369/tcp, 5671-5672/tcp, 15691-15692/tcp, 25672/tcp                                 domain_2-queue-1
# d41bfdbc0c5b   postgres:12                           "docker-entrypoint.s…"   22 hours ago    Up 6 minutes   5432/tcp                                                                            domain_2-db-1
# 7e63446eea66   rabbitmq:3                            "docker-entrypoint.s…"   22 hours ago    Up 6 minutes   4369/tcp, 5671-5672/tcp, 15691-15692/tcp, 25672/tcp                                 domain_1-queue-1
# c4610a4fd890   redis:6.2                             "docker-entrypoint.s…"   22 hours ago    Up 5 minutes   6379/tcp                                                                            domain_1-redis-1
# 4dc63ed3d74f   postgres:12                           "docker-entrypoint.s…"   22 hours ago    Up 6 minutes   5432/tcp                                                                            domain_1-db-1
# 213d75006737   rabbitmq:3                            "docker-entrypoint.s…"   22 hours ago    Up 6 minutes   4369/tcp, 5671-5672/tcp, 15691-15692/tcp, 25672/tcp                                 local_network-queue-1
# 1170ed500e34   redis:6.2                             "docker-entrypoint.s…"   22 hours ago    Up 5 minutes   6379/tcp                                                                            local_network-redis-1
# 0ff1b4d49590   postgres:12                           "docker-entrypoint.s…"   22 hours ago    Up 6 minutes   5432/tcp                                                                            local_network-db-1

# %%
domain_user.apply_to_network(sy.login("localhost", 8000))
# Out:
# Connecting to localhost... done! 	 Logging into local_network... as GUEST...done!
# [1/4] Checking Syft Versions
# [2/4] Joining Network
# [3/4] Connecting to Secure VPN
# [4/4] Registering on the Secure VPN

# %% [markdown]
# ---
#
# # Section 2 : Train the dataset and Upload Weights

# %%
num_clients = 2
manual_seed = 102
trainloaders, valloaders, testloaders = load_datasets(num_clients, manual_seed)

print("\nNumber of train images in domain_2:", len(trainloaders[0]))
print("\nNumber of val images in domain_2:", len(valloaders[0]))
print("\nNumber of test images in domain_2:", len(testloaders[0]))

initial_model = Net()

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(initial_model.parameters(), lr=0.001, momentum=0.9)

i, j = 0, 1
for param in initial_model.parameters():
    
    if i % 2 == 0:
        param.data = torch.FloatTensor(domain_user.datasets[i]["Weight {}".format(j)].get().child.value)
    
    else:    
        param.data = torch.FloatTensor(domain_user.datasets[i]["Bias {}".format(j)].get().child.value)
        j += 1        
        
    i += 1
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
#
# Number of train images in domain_2: 704
#
# Number of val images in domain_2: 79
#
# Number of test images in domain_2: 157

# %%
for epoch in range(10):
    train(initial_model, trainloaders[0], epoch)
    loss, accuracy = test(initial_model, valloaders[0])
    print(f"Epoch {epoch+1}: Validation Loss: {round(loss, 2)}, Accuracy: {round(accuracy*100, 2)}%")
# Out:
# Epoch 1: Validation Loss: 0.17, Accuracy: 48.36%
# Epoch 2: Validation Loss: 0.05, Accuracy: 50.16%
# Epoch 3: Validation Loss: 0.04, Accuracy: 53.68%
# Epoch 4: Validation Loss: 0.04, Accuracy: 55.08%
# Epoch 5: Validation Loss: 0.05, Accuracy: 54.44%
# Epoch 6: Validation Loss: 0.07, Accuracy: 52.24%
# Epoch 7: Validation Loss: 0.09, Accuracy: 50.4%
# Epoch 8: Validation Loss: 0.12, Accuracy: 49.4%
# Epoch 9: Validation Loss: 0.14, Accuracy: 50.84%
# Epoch 10: Validation Loss: 0.17, Accuracy: 50.32%

# %%
domain_user.datasets
# Out:
# <style>
#                 #myInput {
#                   background-position: 10px 12px; /* Position the search icon */
#                   background-repeat: no-repeat; /* Do not repeat the icon image */
#                   background-color: #bbb;
#                   width: 98%; /* Full-width */
#                   font-size: 14px; /* Increase font-size */
#                   padding: 12px 20px 12px 40px; /* Add some padding */
#                   border: 1px solid #ddd; /* Add a grey border */
#                   margin-bottom: 12px; /* Add some space below the input */
#                 }
#
#                 #myTable {
#                   border-collapse: collapse; /* Collapse borders */
#                   width: 100%; /* Full-width */
#                   border: 1px solid #ddd; /* Add a grey border */
#                   font-size: 14px; /* Increase font-size */
#                 }
#
#                 #myTable th, #myTable td {
#                   text-align: left; /* Left-align text */
#                   padding: 10px; /* Add padding */
#                 }
#
#                 #myTable tr {
#                   /* Add a bottom border to all table rows */
#                   border-bottom: 1px solid #ddd;
#                 }
#
#                 #myTable tr.header, #myTable tr:hover {
#                   /* Add a grey background color to the table header and on hover */
#                   background-color: #777;
#                 }
#                 </style>
#
#                 <table id="myTable" style="width:1000px">
#                   <tr class="header">
#                     <th style="width:30px">Idx</th>
#                     <th style="width:20%;">Name</th>
#                     <th style="width:35%;">Description</th>
#                     <th style="width:20%;">Assets</th>
#                     <th style="width:300px;">Id</th>
#                   </tr>
#
#
#           <tr>
#             <td>[0]</td>
#             <td>Initial Weight 1</td>
#             <td>Initial PyTorch weights sent by Network.</td>
#             <td>["Weight 1"] -> Tensor<br /><br /></td>
#             <td>5d4aed9b-2441-468d-bc06-cfb2f0fd61dc</td>
#           </tr>
#
#           <tr>
#             <td>[1]</td>
#             <td>Initial Bias 1</td>
#             <td>Initial PyTorch biases sent by Network.</td>
#             <td>["Bias 1"] -> Tensor<br /><br /></td>
#             <td>209472e3-c907-432c-b8f7-f91076a31e70</td>
#           </tr>
#
#           <tr>
#             <td>[2]</td>
#             <td>Initial Weight 2</td>
#             <td>Initial PyTorch weights sent by Network.</td>
#             <td>["Weight 2"] -> Tensor<br /><br /></td>
#             <td>3152fe92-039b-43f2-87d6-e01cad5151d0</td>
#           </tr>
#
#           <tr>
#             <td>[3]</td>
#             <td>Initial Bias 2</td>
#             <td>Initial PyTorch biases sent by Network.</td>
#             <td>["Bias 2"] -> Tensor<br /><br /></td>
#             <td>262d9293-f797-4678-b13f-7b460b30546e</td>
#           </tr>
#
#           <tr>
#             <td>[4]</td>
#             <td>Initial Weight 3</td>
#             <td>Initial PyTorch weights sent by Network.</td>
#             <td>["Weight 3"] -> Tensor<br /><br /></td>
#             <td>4ec8e1d5-484b-40c5-b40b-5c37e5815e3b</td>
#           </tr>
#
#           <tr>
#             <td>[5]</td>
#             <td>Initial Bias 3</td>
#             <td>Initial PyTorch biases sent by Network.</td>
#             <td>["Bias 3"] -> Tensor<br /><br /></td>
#             <td>16296dd1-9080-4ae8-b357-04509720cf76</td>
#           </tr>
#
#           <tr>
#             <td>[6]</td>
#             <td>Initial Weight 4</td>
#             <td>Initial PyTorch weights sent by Network.</td>
#             <td>["Weight 4"] -> Tensor<br /><br /></td>
#             <td>99758131-00f4-481c-8c05-ceee256c502c</td>
#           </tr>
#
#           <tr>
#             <td>[7]</td>
#             <td>Initial Bias 4</td>
#             <td>Initial PyTorch biases sent by Network.</td>
#             <td>["Bias 4"] -> Tensor<br /><br /></td>
#             <td>91e81bc5-56db-4748-b651-ce8884d66ad0</td>
#           </tr>
#
#           <tr>
#             <td>[8]</td>
#             <td>Initial Weight 5</td>
#             <td>Initial PyTorch weights sent by Network.</td>
#             <td>["Weight 5"] -> Tensor<br /><br /></td>
#             <td>1541bb33-a494-4d3a-9c75-4dac1f72157e</td>
#           </tr>
#
#           <tr>
#             <td>[9]</td>
#             <td>Initial Bias 5</td>
#             <td>Initial PyTorch biases sent by Network.</td>
#             <td>["Bias 5"] -> Tensor<br /><br /></td>
#             <td>42293406-6359-48b2-a0f1-0f97f97afb19</td>
#           </tr>
#         </table>
#
#         <script>
#         function myFunction() {
#           // Declare variables
#           var input, filter, table, tr, td, i, txtValue;
#           input = document.getElementById("myInput");
#           filter = input.value.toUpperCase();
#           table = document.getElementById("myTable");
#           tr = table.getElementsByTagName("tr");
#
#           // Loop through all table rows, and hide those who don't match the search query
#           for (i = 0; i < tr.length; i++) {
#             name_td = tr[i].getElementsByTagName("td")[1];
#             desc_td = tr[i].getElementsByTagName("td")[2];
#             asset_td = tr[i].getElementsByTagName("td")[3];
#             id_td = tr[i].getElementsByTagName("td")[4];
#             if (name_td || desc_td || asset_td || id_td) {
#               name_txtValue = name_td.textContent || name_td.innerText;
#               desc_txtValue = desc_td.textContent || name_td.innerText;
#               asset_txtValue = asset_td.textContent || name_td.innerText;
#               id_txtValue = id_td.textContent || name_td.innerText;
#               name_bool = name_txtValue.toUpperCase().indexOf(filter) > -1;
#               desc_bool = desc_txtValue.toUpperCase().indexOf(filter) > -1;
#               asset_bool = asset_txtValue.toUpperCase().indexOf(filter) > -1;
#               id_bool = id_txtValue.toUpperCase().indexOf(filter) > -1;
#               if (name_bool || desc_bool || asset_bool || id_bool) {
#                 tr[i].style.display = "";
#               } else {
#                 tr[i].style.display = "none";
#               }
#             }
#           }
#         }
#         </script>

# %%
i, j = 0, 0
for layer in initial_model.children():
        
    if "weight" in layer.state_dict():
        i += 1
            
        model_weights = layer.state_dict()["weight"]
        weights_tensor = sy.Tensor(model_weights).annotate_with_dp_metadata(lower_bound=-1, upper_bound=1, data_subject="PyTorch Weights")

        domain_user.load_dataset(assets={"Weight {}".format(i): weights_tensor},
                              name="Domain Weight {}".format(i),
                              description="Updated PyTorch weights sent by Domain.")

    if "bias" in layer.state_dict():
        j += 1

        model_bias = layer.state_dict()["bias"]
        bias_tensor = sy.Tensor(model_bias).annotate_with_dp_metadata(lower_bound=-1, upper_bound=1, data_subject="PyTorch Bias")

        domain_user.load_dataset(assets={"Bias {}".format(j): bias_tensor},
                              name="Domain Bias {}".format(j),
                              description="Updated PyTorch biases sent by Domain.")
# Out:
# Converting PyTorch tensor to numpy tensor for internal representation...
# Tensor annotated with DP Metadata!
# You can upload this Tensor to a domain node by calling `<domain_client>.load_dataset` and passing in this tensor as an asset.
# Loading dataset... uploading...🚀
# Uploading `Weight 1`: 100%|███████████████████████████████████████████| 1/1 [00:00<00:00, 75.41it/s]
# Dataset is uploaded successfully !!! 🎉
#
# Run `<your client variable>.datasets` to see your new dataset loaded into your machine!
# Converting PyTorch tensor to numpy tensor for internal representation...
# Tensor annotated with DP Metadata!
# You can upload this Tensor to a domain node by calling `<domain_client>.load_dataset` and passing in this tensor as an asset.
# Loading dataset... uploading...🚀
# Uploading `Bias 1`: 100%|████████████████████████████████████████████| 1/1 [00:00<00:00, 138.62it/s]
# Dataset is uploaded successfully !!! 🎉
#
# Run `<your client variable>.datasets` to see your new dataset loaded into your machine!
# Converting PyTorch tensor to numpy tensor for internal representation...
# Tensor annotated with DP Metadata!
# You can upload this Tensor to a domain node by calling `<domain_client>.load_dataset` and passing in this tensor as an asset.
# Loading dataset... uploading...🚀
# Uploading `Weight 2`: 100%|██████████████████████████████████████████| 1/1 [00:00<00:00, 168.41it/s]
# Dataset is uploaded successfully !!! 🎉
#
# Run `<your client variable>.datasets` to see your new dataset loaded into your machine!
# Converting PyTorch tensor to numpy tensor for internal representation...
# Tensor annotated with DP Metadata!
# You can upload this Tensor to a domain node by calling `<domain_client>.load_dataset` and passing in this tensor as an asset.
# Loading dataset... uploading...🚀
# Uploading `Bias 2`: 100%|████████████████████████████████████████████| 1/1 [00:00<00:00, 192.45it/s]
# Dataset is uploaded successfully !!! 🎉
#
# Run `<your client variable>.datasets` to see your new dataset loaded into your machine!
# Converting PyTorch tensor to numpy tensor for internal representation...
# Tensor annotated with DP Metadata!
# You can upload this Tensor to a domain node by calling `<domain_client>.load_dataset` and passing in this tensor as an asset.
# Loading dataset... uploading...🚀
# Uploading `Weight 3`: 100%|███████████████████████████████████████████| 1/1 [00:00<00:00, 42.12it/s]
# Dataset is uploaded successfully !!! 🎉
#
# Run `<your client variable>.datasets` to see your new dataset loaded into your machine!
# Converting PyTorch tensor to numpy tensor for internal representation...
# Tensor annotated with DP Metadata!
# You can upload this Tensor to a domain node by calling `<domain_client>.load_dataset` and passing in this tensor as an asset.
# Loading dataset... uploading...🚀
# Uploading `Bias 3`: 100%|████████████████████████████████████████████| 1/1 [00:00<00:00, 144.70it/s]
# Dataset is uploaded successfully !!! 🎉
#
# Run `<your client variable>.datasets` to see your new dataset loaded into your machine!
# Converting PyTorch tensor to numpy tensor for internal representation...
# Tensor annotated with DP Metadata!
# You can upload this Tensor to a domain node by calling `<domain_client>.load_dataset` and passing in this tensor as an asset.
# Loading dataset... uploading...🚀
# Uploading `Weight 4`: 100%|██████████████████████████████████████████| 1/1 [00:00<00:00, 157.93it/s]
# Dataset is uploaded successfully !!! 🎉
#
# Run `<your client variable>.datasets` to see your new dataset loaded into your machine!
# Converting PyTorch tensor to numpy tensor for internal representation...
# Tensor annotated with DP Metadata!
# You can upload this Tensor to a domain node by calling `<domain_client>.load_dataset` and passing in this tensor as an asset.
# Loading dataset... uploading...🚀
# Uploading `Bias 4`: 100%|████████████████████████████████████████████| 1/1 [00:00<00:00, 217.72it/s]
# Dataset is uploaded successfully !!! 🎉
#
# Run `<your client variable>.datasets` to see your new dataset loaded into your machine!
# Converting PyTorch tensor to numpy tensor for internal representation...
# Tensor annotated with DP Metadata!
# You can upload this Tensor to a domain node by calling `<domain_client>.load_dataset` and passing in this tensor as an asset.
# Loading dataset... uploading...🚀
# Uploading `Weight 5`: 100%|██████████████████████████████████████████| 1/1 [00:00<00:00, 180.91it/s]
# Dataset is uploaded successfully !!! 🎉
#
# Run `<your client variable>.datasets` to see your new dataset loaded into your machine!
# Converting PyTorch tensor to numpy tensor for internal representation...
# Tensor annotated with DP Metadata!
# You can upload this Tensor to a domain node by calling `<domain_client>.load_dataset` and passing in this tensor as an asset.
# Loading dataset... uploading...🚀
# Uploading `Bias 5`: 100%|████████████████████████████████████████████| 1/1 [00:00<00:00, 222.51it/s]
# Dataset is uploaded successfully !!! 🎉
#
# Run `<your client variable>.datasets` to see your new dataset loaded into your machine!

# %%
domain_user.datasets
# Out:
# <style>
#                 #myInput {
#                   background-position: 10px 12px; /* Position the search icon */
#                   background-repeat: no-repeat; /* Do not repeat the icon image */
#                   background-color: #bbb;
#                   width: 98%; /* Full-width */
#                   font-size: 14px; /* Increase font-size */
#                   padding: 12px 20px 12px 40px; /* Add some padding */
#                   border: 1px solid #ddd; /* Add a grey border */
#                   margin-bottom: 12px; /* Add some space below the input */
#                 }
#
#                 #myTable {
#                   border-collapse: collapse; /* Collapse borders */
#                   width: 100%; /* Full-width */
#                   border: 1px solid #ddd; /* Add a grey border */
#                   font-size: 14px; /* Increase font-size */
#                 }
#
#                 #myTable th, #myTable td {
#                   text-align: left; /* Left-align text */
#                   padding: 10px; /* Add padding */
#                 }
#
#                 #myTable tr {
#                   /* Add a bottom border to all table rows */
#                   border-bottom: 1px solid #ddd;
#                 }
#
#                 #myTable tr.header, #myTable tr:hover {
#                   /* Add a grey background color to the table header and on hover */
#                   background-color: #777;
#                 }
#                 </style>
#
#                 <table id="myTable" style="width:1000px">
#                   <tr class="header">
#                     <th style="width:30px">Idx</th>
#                     <th style="width:20%;">Name</th>
#                     <th style="width:35%;">Description</th>
#                     <th style="width:20%;">Assets</th>
#                     <th style="width:300px;">Id</th>
#                   </tr>
#
#
#           <tr>
#             <td>[0]</td>
#             <td>Initial Weight 1</td>
#             <td>Initial PyTorch weights sent by Network.</td>
#             <td>["Weight 1"] -> Tensor<br /><br /></td>
#             <td>5d4aed9b-2441-468d-bc06-cfb2f0fd61dc</td>
#           </tr>
#
#           <tr>
#             <td>[1]</td>
#             <td>Initial Bias 1</td>
#             <td>Initial PyTorch biases sent by Network.</td>
#             <td>["Bias 1"] -> Tensor<br /><br /></td>
#             <td>209472e3-c907-432c-b8f7-f91076a31e70</td>
#           </tr>
#
#           <tr>
#             <td>[2]</td>
#             <td>Initial Weight 2</td>
#             <td>Initial PyTorch weights sent by Network.</td>
#             <td>["Weight 2"] -> Tensor<br /><br /></td>
#             <td>3152fe92-039b-43f2-87d6-e01cad5151d0</td>
#           </tr>
#
#           <tr>
#             <td>[3]</td>
#             <td>Initial Bias 2</td>
#             <td>Initial PyTorch biases sent by Network.</td>
#             <td>["Bias 2"] -> Tensor<br /><br /></td>
#             <td>262d9293-f797-4678-b13f-7b460b30546e</td>
#           </tr>
#
#           <tr>
#             <td>[4]</td>
#             <td>Initial Weight 3</td>
#             <td>Initial PyTorch weights sent by Network.</td>
#             <td>["Weight 3"] -> Tensor<br /><br /></td>
#             <td>4ec8e1d5-484b-40c5-b40b-5c37e5815e3b</td>
#           </tr>
#
#           <tr>
#             <td>[5]</td>
#             <td>Initial Bias 3</td>
#             <td>Initial PyTorch biases sent by Network.</td>
#             <td>["Bias 3"] -> Tensor<br /><br /></td>
#             <td>16296dd1-9080-4ae8-b357-04509720cf76</td>
#           </tr>
#
#           <tr>
#             <td>[6]</td>
#             <td>Initial Weight 4</td>
#             <td>Initial PyTorch weights sent by Network.</td>
#             <td>["Weight 4"] -> Tensor<br /><br /></td>
#             <td>99758131-00f4-481c-8c05-ceee256c502c</td>
#           </tr>
#
#           <tr>
#             <td>[7]</td>
#             <td>Initial Bias 4</td>
#             <td>Initial PyTorch biases sent by Network.</td>
#             <td>["Bias 4"] -> Tensor<br /><br /></td>
#             <td>91e81bc5-56db-4748-b651-ce8884d66ad0</td>
#           </tr>
#
#           <tr>
#             <td>[8]</td>
#             <td>Initial Weight 5</td>
#             <td>Initial PyTorch weights sent by Network.</td>
#             <td>["Weight 5"] -> Tensor<br /><br /></td>
#             <td>1541bb33-a494-4d3a-9c75-4dac1f72157e</td>
#           </tr>
#
#           <tr>
#             <td>[9]</td>
#             <td>Initial Bias 5</td>
#             <td>Initial PyTorch biases sent by Network.</td>
#             <td>["Bias 5"] -> Tensor<br /><br /></td>
#             <td>42293406-6359-48b2-a0f1-0f97f97afb19</td>
#           </tr>
#
#           <tr>
#             <td>[10]</td>
#             <td>Domain Weight 1</td>
#             <td>Updated PyTorch weights sent by Domain.</td>
#             <td>["Weight 1"] -> Tensor<br /><br /></td>
#             <td>d77f439a-c543-491d-bd0f-30500a005432</td>
#           </tr>
#
#           <tr>
#             <td>[11]</td>
#             <td>Domain Bias 1</td>
#             <td>Updated PyTorch biases sent by Domain.</td>
#             <td>["Bias 1"] -> Tensor<br /><br /></td>
#             <td>caf68cf1-ea9a-401b-ae64-e13d247baa4d</td>
#           </tr>
#
#           <tr>
#             <td>[12]</td>
#             <td>Domain Weight 2</td>
#             <td>Updated PyTorch weights sent by Domain.</td>
#             <td>["Weight 2"] -> Tensor<br /><br /></td>
#             <td>0fb772c2-d51a-41bf-bf6c-150d7ffa8013</td>
#           </tr>
#
#           <tr>
#             <td>[13]</td>
#             <td>Domain Bias 2</td>
#             <td>Updated PyTorch biases sent by Domain.</td>
#             <td>["Bias 2"] -> Tensor<br /><br /></td>
#             <td>f8ba7c4c-3444-4e83-9e61-8d4110746a5b</td>
#           </tr>
#
#           <tr>
#             <td>[14]</td>
#             <td>Domain Weight 3</td>
#             <td>Updated PyTorch weights sent by Domain.</td>
#             <td>["Weight 3"] -> Tensor<br /><br /></td>
#             <td>139093c7-7cdf-423a-93e6-604e360b5244</td>
#           </tr>
#
#           <tr>
#             <td>[15]</td>
#             <td>Domain Bias 3</td>
#             <td>Updated PyTorch biases sent by Domain.</td>
#             <td>["Bias 3"] -> Tensor<br /><br /></td>
#             <td>3bc415fe-0b16-4643-944e-f33aece74ad2</td>
#           </tr>
#
#           <tr>
#             <td>[16]</td>
#             <td>Domain Weight 4</td>
#             <td>Updated PyTorch weights sent by Domain.</td>
#             <td>["Weight 4"] -> Tensor<br /><br /></td>
#             <td>e7555f44-ed13-41e6-afb0-fa424ab8ada0</td>
#           </tr>
#
#           <tr>
#             <td>[17]</td>
#             <td>Domain Bias 4</td>
#             <td>Updated PyTorch biases sent by Domain.</td>
#             <td>["Bias 4"] -> Tensor<br /><br /></td>
#             <td>eb3463ee-0488-43b7-8e4b-a4bde85b7cb8</td>
#           </tr>
#
#           <tr>
#             <td>[18]</td>
#             <td>Domain Weight 5</td>
#             <td>Updated PyTorch weights sent by Domain.</td>
#             <td>["Weight 5"] -> Tensor<br /><br /></td>
#             <td>3dbd163b-b843-4e80-835e-e5c4c24d5fb4</td>
#           </tr>
#
#           <tr>
#             <td>[19]</td>
#             <td>Domain Bias 5</td>
#             <td>Updated PyTorch biases sent by Domain.</td>
#             <td>["Bias 5"] -> Tensor<br /><br /></td>
#             <td>44046f17-016a-41e8-a0b3-08fb2099ca66</td>
#           </tr>
#         </table>
#
#         <script>
#         function myFunction() {
#           // Declare variables
#           var input, filter, table, tr, td, i, txtValue;
#           input = document.getElementById("myInput");
#           filter = input.value.toUpperCase();
#           table = document.getElementById("myTable");
#           tr = table.getElementsByTagName("tr");
#
#           // Loop through all table rows, and hide those who don't match the search query
#           for (i = 0; i < tr.length; i++) {
#             name_td = tr[i].getElementsByTagName("td")[1];
#             desc_td = tr[i].getElementsByTagName("td")[2];
#             asset_td = tr[i].getElementsByTagName("td")[3];
#             id_td = tr[i].getElementsByTagName("td")[4];
#             if (name_td || desc_td || asset_td || id_td) {
#               nam

# %% [markdown]
# ---
#
# # Section 3: Test on Aggregated Weights
#
# <h3 style="color:red;">Run the below cells after running Section 3 in Network notebook</h3>

# %%
domain_user.datasets
# Out:
# <style>
#                 #myInput {
#                   background-position: 10px 12px; /* Position the search icon */
#                   background-repeat: no-repeat; /* Do not repeat the icon image */
#                   background-color: #bbb;
#                   width: 98%; /* Full-width */
#                   font-size: 14px; /* Increase font-size */
#                   padding: 12px 20px 12px 40px; /* Add some padding */
#                   border: 1px solid #ddd; /* Add a grey border */
#                   margin-bottom: 12px; /* Add some space below the input */
#                 }
#
#                 #myTable {
#                   border-collapse: collapse; /* Collapse borders */
#                   width: 100%; /* Full-width */
#                   border: 1px solid #ddd; /* Add a grey border */
#                   font-size: 14px; /* Increase font-size */
#                 }
#
#                 #myTable th, #myTable td {
#                   text-align: left; /* Left-align text */
#                   padding: 10px; /* Add padding */
#                 }
#
#                 #myTable tr {
#                   /* Add a bottom border to all table rows */
#                   border-bottom: 1px solid #ddd;
#                 }
#
#                 #myTable tr.header, #myTable tr:hover {
#                   /* Add a grey background color to the table header and on hover */
#                   background-color: #777;
#                 }
#                 </style>
#
#                 <table id="myTable" style="width:1000px">
#                   <tr class="header">
#                     <th style="width:30px">Idx</th>
#                     <th style="width:20%;">Name</th>
#                     <th style="width:35%;">Description</th>
#                     <th style="width:20%;">Assets</th>
#                     <th style="width:300px;">Id</th>
#                   </tr>
#
#
#           <tr>
#             <td>[0]</td>
#             <td>Initial Weight 1</td>
#             <td>Initial PyTorch weights sent by Network.</td>
#             <td>["Weight 1"] -> Tensor<br /><br /></td>
#             <td>5d4aed9b-2441-468d-bc06-cfb2f0fd61dc</td>
#           </tr>
#
#           <tr>
#             <td>[1]</td>
#             <td>Initial Bias 1</td>
#             <td>Initial PyTorch biases sent by Network.</td>
#             <td>["Bias 1"] -> Tensor<br /><br /></td>
#             <td>209472e3-c907-432c-b8f7-f91076a31e70</td>
#           </tr>
#
#           <tr>
#             <td>[2]</td>
#             <td>Initial Weight 2</td>
#             <td>Initial PyTorch weights sent by Network.</td>
#             <td>["Weight 2"] -> Tensor<br /><br /></td>
#             <td>3152fe92-039b-43f2-87d6-e01cad5151d0</td>
#           </tr>
#
#           <tr>
#             <td>[3]</td>
#             <td>Initial Bias 2</td>
#             <td>Initial PyTorch biases sent by Network.</td>
#             <td>["Bias 2"] -> Tensor<br /><br /></td>
#             <td>262d9293-f797-4678-b13f-7b460b30546e</td>
#           </tr>
#
#           <tr>
#             <td>[4]</td>
#             <td>Initial Weight 3</td>
#             <td>Initial PyTorch weights sent by Network.</td>
#             <td>["Weight 3"] -> Tensor<br /><br /></td>
#             <td>4ec8e1d5-484b-40c5-b40b-5c37e5815e3b</td>
#           </tr>
#
#           <tr>
#             <td>[5]</td>
#             <td>Initial Bias 3</td>
#             <td>Initial PyTorch biases sent by Network.</td>
#             <td>["Bias 3"] -> Tensor<br /><br /></td>
#             <td>16296dd1-9080-4ae8-b357-04509720cf76</td>
#           </tr>
#
#           <tr>
#             <td>[6]</td>
#             <td>Initial Weight 4</td>
#             <td>Initial PyTorch weights sent by Network.</td>
#             <td>["Weight 4"] -> Tensor<br /><br /></td>
#             <td>99758131-00f4-481c-8c05-ceee256c502c</td>
#           </tr>
#
#           <tr>
#             <td>[7]</td>
#             <td>Initial Bias 4</td>
#             <td>Initial PyTorch biases sent by Network.</td>
#             <td>["Bias 4"] -> Tensor<br /><br /></td>
#             <td>91e81bc5-56db-4748-b651-ce8884d66ad0</td>
#           </tr>
#
#           <tr>
#             <td>[8]</td>
#             <td>Initial Weight 5</td>
#             <td>Initial PyTorch weights sent by Network.</td>
#             <td>["Weight 5"] -> Tensor<br /><br /></td>
#             <td>1541bb33-a494-4d3a-9c75-4dac1f72157e</td>
#           </tr>
#
#           <tr>
#             <td>[9]</td>
#             <td>Initial Bias 5</td>
#             <td>Initial PyTorch biases sent by Network.</td>
#             <td>["Bias 5"] -> Tensor<br /><br /></td>
#             <td>42293406-6359-48b2-a0f1-0f97f97afb19</td>
#           </tr>
#
#           <tr>
#             <td>[10]</td>
#             <td>Domain Weight 1</td>
#             <td>Updated PyTorch weights sent by Domain.</td>
#             <td>["Weight 1"] -> Tensor<br /><br /></td>
#             <td>d77f439a-c543-491d-bd0f-30500a005432</td>
#           </tr>
#
#           <tr>
#             <td>[11]</td>
#             <td>Domain Bias 1</td>
#             <td>Updated PyTorch biases sent by Domain.</td>
#             <td>["Bias 1"] -> Tensor<br /><br /></td>
#             <td>caf68cf1-ea9a-401b-ae64-e13d247baa4d</td>
#           </tr>
#
#           <tr>
#             <td>[12]</td>
#             <td>Domain Weight 2</td>
#             <td>Updated PyTorch weights sent by Domain.</td>
#             <td>["Weight 2"] -> Tensor<br /><br /></td>
#             <td>0fb772c2-d51a-41bf-bf6c-150d7ffa8013</td>
#           </tr>
#
#           <tr>
#             <td>[13]</td>
#             <td>Domain Bias 2</td>
#             <td>Updated PyTorch biases sent by Domain.</td>
#             <td>["Bias 2"] -> Tensor<br /><br /></td>
#             <td>f8ba7c4c-3444-4e83-9e61-8d4110746a5b</td>
#           </tr>
#
#           <tr>
#             <td>[14]</td>
#             <td>Domain Weight 3</td>
#             <td>Updated PyTorch weights sent by Domain.</td>
#             <td>["Weight 3"] -> Tensor<br /><br /></td>
#             <td>139093c7-7cdf-423a-93e6-604e360b5244</td>
#           </tr>
#
#           <tr>
#             <td>[15]</td>
#             <td>Domain Bias 3</td>
#             <td>Updated PyTorch biases sent by Domain.</td>
#             <td>["Bias 3"] -> Tensor<br /><br /></td>
#             <td>3bc415fe-0b16-4643-944e-f33aece74ad2</td>
#           </tr>
#
#           <tr>
#             <td>[16]</td>
#             <td>Domain Weight 4</td>
#             <td>Updated PyTorch weights sent by Domain.</td>
#             <td>["Weight 4"] -> Tensor<br /><br /></td>
#             <td>e7555f44-ed13-41e6-afb0-fa424ab8ada0</td>
#           </tr>
#
#           <tr>
#             <td>[17]</td>
#             <td>Domain Bias 4</td>
#             <td>Updated PyTorch biases sent by Domain.</td>
#             <td>["Bias 4"] -> Tensor<br /><br /></td>
#             <td>eb3463ee-0488-43b7-8e4b-a4bde85b7cb8</td>
#           </tr>
#
#           <tr>
#             <td>[18]</td>
#             <td>Domain Weight 5</td>
#             <td>Updated PyTorch weights sent by Domain.</td>
#             <td>["Weight 5"] -> Tensor<br /><br /></td>
#             <td>3dbd163b-b843-4e80-835e-e5c4c24d5fb4</td>
#           </tr>
#
#           <tr>
#             <td>[19]</td>
#             <td>Domain Bias 5</td>
#             <td>Updated PyTorch biases sent by Domain.</td>
#             <td>["Bias 5"] -> Tensor<br /><br /></td>
#             <td>44046f17-016a-41e8-a0b3-08fb2099ca66</td>
#           </tr>
#
#           <tr>
#             <td>[20]</td>
#             <td>Final Weight 1</td>
#             <td>Final PyTorch weights sent by Network.</td>
#             <td>["Weight 1"] -> Tensor<br /><br /></td>
#             <td>57bff453-4f21-4fea-b515-467f05a80ced</td>
#           </tr>
#
#           <tr>
#             <td>[21]</td>
#             <td>Final Bias 1</td>
#             <td>Final PyTorch biases sent by Network.</td>
#             <td>["Bias 1"] -> Tensor<br /><br /></td>
#             <td>341804e0-5834-46e3-9092-e64a9d342398</td>
#           </tr>
#
#           <tr>
#             <td>[22]</td>
#             <td>Final Weight 2</td>
#             <td>Final PyTorch weights sent by Network.</td>
#             <td>["Weight 2"] -> Tensor<br /><br /></td>
#             <td>7878e698-59d4-4b84-b639-6fb52f976622</td>
#           </tr>

# %%
num_clients = 2
manual_seed = 102
trainloaders, valloaders, testloaders = load_datasets(num_clients, manual_seed)

loss, accuracy = test(initial_model, testloaders[0])
print(f"Initial model performance: \n\tLoss {round(loss, 2)}\n\tAccuracy: {round(accuracy*100, 2)}%")

agg_model = Net() # 47%

i, j = 20, 1
for param in agg_model.parameters():
    
    if i % 2 == 0:
        param.data = torch.FloatTensor(domain_user.datasets[i]["Weight {}".format(j)].get().child.value)
    
    else:    
        param.data = torch.FloatTensor(domain_user.datasets[i]["Bias {}".format(j)].get().child.value)
        j += 1        
        
    i += 1
    
    
loss, accuracy = test(agg_model, testloaders[0])
print(f"\nAggregated model performance:\n \tLoss {round(loss, 2)}\n\tAccuracy: {round(accuracy*100, 2)}%")
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Initial model performance:
# 	Loss 0.16
# 	Accuracy: 50.3%
#
# Aggregated model performance:
#  	Loss 0.13
# 	Accuracy: 53.54%

# %% [markdown]
# ---
